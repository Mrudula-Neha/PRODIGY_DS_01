# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
df = sns.load_dataset("penguins")

# %%
data=pd.read_csv("Data.csv")

# %%
data.head()
# Out:
#    applicant_id  years_of_insurance_with_us  regular_checkup_lasy_year  \
# 0          5000                           3                          1
# 1          5001                           0                          0
# 2          5002                           1                          0
# 3          5003                           7                          4
# 4          5004                           3                          1
#
#    adventure_sports Occupation  visited_doctor_last_1_year cholesterol_level  \
# 0                 1    Salried                           2        125 to 150
# 1                 0    Student                           4        150 to 175
# 2                 0   Business                           4        200 to 225
# 3                 0   Business                           2        175 to 200
# 4                 0    Student                           2        150 to 175
#
#    daily_avg_steps  age  heart_decs_history  ...   smoking_status  \
# ...

# %%
data.tail()
# Out:
#        applicant_id  years_of_insurance_with_us  regular_checkup_lasy_year  \
# 24995         29995                           3                          0
# 24996         29996                           6                          0
# 24997         29997                           7                          0
# 24998         29998                           1                          0
# 24999         29999                           8                          2
#
#        adventure_sports Occupation  visited_doctor_last_1_year  \
# 24995                 0    Salried                           4
# 24996                 0   Business                           4
# 24997                 1    Student                           2
# 24998                 0    Salried                           2
# 24999                 0   Business                           4
#
#       cholesterol_level  daily_avg_steps  age  heart_decs_history  ...  \
# ...

# %%
print("No. of Rows :",data.shape[0])
print("No. of Columns :",data.shape[1])
# Out:
# No. of Rows : 25000
# No. of Columns : 24

# %%
sns.countplot(x=data['adventure_sports'])
plt.show()

# %%
sns.countplot(x=data['regular_checkup_lasy_year'])
plt.show()

# %%
sns.countplot(x=data['heart_decs_history'])
plt.show()

# %%
sns.countplot(x=data['Gender'])
plt.show()

# %%
sns.countplot(x=data['years_of_insurance_with_us'])
plt.show()

# %%
sns.countplot(x=data['Alcohol'])
plt.show()

# %%
sns.countplot(x=data['Occupation'])
plt.show()

# %%
sns.countplot(x=data['other_major_decs_history'])
plt.show()

# %%
sns.countplot(x=data['smoking_status'])
plt.show()

# %%
sns.histplot(data['age'],bins=20, stat="count",color='red',kde=False)
plt.title("Age Distribution")
plt.show()

# %%
sns.histplot(data['cholesterol_level'],bins=20, stat="count",color='blue')
plt.show()

# %%
sns.histplot(data['daily_avg_steps'],bins=20, stat="count",color='green',kde=True)
plt.show()

# %%
sns.histplot(data['avg_glucose_level'],bins=20, stat="count",color='pink')
plt.show()

# %%
sns.histplot(data['bmi'],bins=20, stat="count",color='violet',kde=True)
plt.show()

# %%
sns.histplot(data['weight'],bins=20, stat="count",color='red',kde=True)
plt.show()

# %%
sns.histplot(data['fat_percentage'],bins=20, stat="count",color='blue')
plt.show()

# %%
sns.histplot(data['insurance_cost'],bins=20, stat="count",color='orange')
plt.show()
